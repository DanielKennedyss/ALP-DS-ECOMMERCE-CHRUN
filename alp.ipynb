# %% [markdown]
# # Data Science Capstone Project: E-commerce Customer Churn Prediction
# **Group:** Cry Me a River
# **Team Members:**
# 1. Daniel Roger Kennedy
# 2. Lennard Lucius Huang
# 3. Akhnan Iban Fahrezi

# %% [markdown]
# ---
#
# ## 1. Business Understanding (CRISP-DM Phase)
# > **"Turning Data into Entrepreneurial Insight"**
#
# **Project Objective:** To develop a predictive machine learning model for identifying customers at risk of *churn*.
#
# **Business Impact:** In the e-commerce sector, customer retention is significantly more cost-effective than customer acquisition. By implementing a proactive retention strategy—such as personalized discounts or service recovery—the company can minimize revenue loss and optimize *Customer Lifetime Value* (CLV).

# %% [markdown]
# ---
#
# ## 2. Exploratory Data Analysis (EDA)
#
# ### 📊 Univariate Analysis: Target Variable Distribution
# This analysis examines the ratio between churned and retained customers. Understanding class distribution is critical to identify potential class imbalance, which directly influences our choice of evaluation metrics (Recall and F1-Score).
#
#
#
# ### 🔗 Multivariate Analysis: Correlation Matrix
# The heatmap below visualizes the correlation between numerical variables. Identifying features with strong relationships to the 'Churn' target will assist in feature selection and provide deeper insights into customer behavior.

# %%
# 1. Importing Essential Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Setting the visual style for professional-grade charts
sns.set_theme(style="whitegrid")
plt.rcParams['figure.figsize'] = (12, 6)

# 2. Loading the Dataset
# We use 'read_excel' because your file format is .xlsx
# Make sure the file name matches exactly
file_name = 'EComm.csv' 

try:
    df = pd.read_csv(file_name)
    print("Dataset successfully loaded!")
    print(f"Dataset dimensions: {df.shape[0]} rows and {df.shape[1]} columns")
except FileNotFoundError:
    print(f"Error: The file '{file_name}' was not found. Please check the file path.")

# Displaying first 5 rows to verify structure
df.head()
# Out:
# Dataset successfully loaded!
# Dataset dimensions: 5630 rows and 20 columns
#    CustomerID  Churn  Tenure PreferredLoginDevice  CityTier  WarehouseToHome  \
# 0       50001      1     4.0         Mobile Phone         3              6.0
# 1       50002      1     NaN                Phone         1              8.0
# 2       50003      1     NaN                Phone         1             30.0
# 3       50004      1     0.0                Phone         3             15.0
# 4       50005      1     0.0                Phone         1             12.0
#
#   PreferredPaymentMode  Gender  HourSpendOnApp  NumberOfDeviceRegistered  \
# 0           Debit Card  Female             3.0                         3
# 1                  UPI    Male             3.0                         4
# 2           Debit Card    Male             2.0                         4
# 3           Debit Card    Male             2.0                         4
# ...
